# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import pyzbar.pyzbar as pyzbar

# %%
img = cv2.imread('qr/0038.bmp')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# img = cv2.resize(img, (0, 0), fx=2.5, fy=2.5)
barcodes=pyzbar.decode(img)
print(barcodes)
plt.imshow(img, cmap='gray')
# Out:
# []

# %%
r, c = img.shape
crop = img[6:r-6, 6:c-6]
recog_qr(crop)
# Out:
# (-1, '')

# %%
r, c = img.shape

rate = 0.8
divide = 0.4

crop_x = int(c * divide)

left_img = img[:, :crop_x]
right_img = img[:, crop_x:]

plt.imshow(left_img, cmap='gray')

# %%
rl, cl = left_img.shape
left_img2 = cv2.resize(left_img, (int(cl*rate),  rl))
plt.imshow(left_img2, cmap='gray')

# %%
fit_img = np.hstack([left_img2, right_img])
plt.imshow(fit_img, cmap='gray')

# %%
recog_qr(fit_img)
# Out:
# (0,
#  '030755010316505862241125261889992389638269950028739393303410107418124646925447071471998936107042924718513843814341408380917162804569442148109605')
